# %% [markdown]
# # IMPORT

# %%
# %run functions.ipynb

# %% [markdown]
# # display mr, pr, dc

# %% [markdown]
# # display AA00

# %%
# Exemple d’utilisation

displaywithspetialtimes("AA00")

# %% [markdown]
# # affichage de tout les patients en indiquant les temps specifiques

# %%
patients_en_erreur = []
for code_patient in df_codesPatients["Code Patient"]:
    try:
        columns = ['Sample', 'Date', 'Time', '3 PU', 'Missing value 1', 'Missing value 2']
        displaywithspetialtimes(code_patient)
    except Exception as e:
        patients_en_erreur.append(code_patient)
        print("========",code_patient,"=========")
        print(f"Erreur pour {code_patient} : {e}")
